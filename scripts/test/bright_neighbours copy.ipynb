# %%
from astroquery.gaia import Gaia

import numpy as np
import pandas as pd
import sys
sys.path.append('../../scripts/')
from query import *

# %%
# Query parameters
TARGET_G_MAG_LIMIT = 6  # gs.phot_g_mean_mag < TARGET_G_MAG_LIMIT
NEIGHBOR_G_MAG_LIMIT = TARGET_G_MAG_LIMIT + 1  # neighbors.phot_g_mean_mag < NEIGHBOR_G_MAG_LIMIT
MIN_DEC = -85  # gs.dec >= MIN_DEC
MAX_DEC = 30  # gs.dec <= MAX_DEC
MIN_PARALLAX = 20  # gs.parallax >= MIN_PARALLAX (MAX_DISTANCE = 1000/MIN_PARALLAX)

# %%
query_all_stars = f"""
SELECT gs.source_id AS dr2_source_id,
    gs.ra, 
    gs.dec, 
    gs.phot_g_mean_mag, 
    gs.phot_bp_mean_mag, 
    gs.phot_rp_mean_mag, 
    gs.bp_rp, 
    gs.parallax
FROM gaiadr2.gaia_source AS gs
WHERE gs.phot_g_mean_mag < {TARGET_G_MAG_LIMIT}
    AND gs.dec BETWEEN {MIN_DEC} AND {MAX_DEC}
    AND gs.parallax >= {MIN_PARALLAX} 
"""

no_bright_neighbor_query = f"""
SELECT 
    gs.source_id, 
    gs.ra, 
    gs.dec, 
    gs.phot_g_mean_mag
FROM 
    gaiadr2.gaia_source AS gs
WHERE 
    gs.phot_g_mean_mag < {TARGET_G_MAG_LIMIT}
    AND gs.dec BETWEEN {MIN_DEC} AND {MAX_DEC}
    AND gs.parallax >= {MIN_PARALLAX}
    AND NOT EXISTS (
        SELECT 1
        FROM gaiadr2.gaia_source AS neighbors
        WHERE 
            1=CONTAINS(
                POINT('ICRS', gs.ra, gs.dec),
                CIRCLE('ICRS', neighbors.ra, neighbors.dec, 2/3600.0)
            )
            AND neighbors.phot_g_mean_mag < {NEIGHBOR_G_MAG_LIMIT}
            AND gs.source_id != neighbors.source_id
    )
"""

bright_neighbor_query = f"""
SELECT 
    gs.source_id, 
    gs.ra, 
    gs.dec, 
    gs.phot_g_mean_mag, 
    neighbors.source_id AS neighbor_id,
    neighbors.phot_g_mean_mag AS neighbor_mag,
    DISTANCE(
        POINT('ICRS', gs.ra, gs.dec), 
        POINT('ICRS', neighbors.ra, neighbors.dec)
    ) AS angular_distance
FROM 
    gaiadr2.gaia_source AS gs
JOIN 
    gaiadr2.gaia_source AS neighbors
ON 
    1=CONTAINS(
        POINT('ICRS', gs.ra, gs.dec),
        CIRCLE('ICRS', neighbors.ra, neighbors.dec, 2/3600.0)
    )
WHERE 
    gs.phot_g_mean_mag < {TARGET_G_MAG_LIMIT}
    AND gs.dec BETWEEN {MIN_DEC} AND {MAX_DEC}
    AND gs.parallax >= {MIN_PARALLAX}
    AND neighbors.phot_g_mean_mag < {NEIGHBOR_G_MAG_LIMIT}
    AND gs.source_id != neighbors.source_id
"""

# ... rest of the code remains the same ...

# %%
if 1: # For the all stars query
    df_all_stars = execute_gaia_query(
        query_all_stars,
        str_columns=['dr2_source_id'],
        output_file='all_stars_dr2.xlsx'
    )

if 1: # For the no bright neighbor query
    df_no_bright_neighbor = execute_gaia_query(
        no_bright_neighbor_query,
        str_columns=['source_id'],
        output_file='no_bright_neighbor_results.xlsx'
    )

if 1: # For the bright neighbor query
    df_bright_neighbor = execute_gaia_query(
        bright_neighbor_query,
        str_columns=['source_id', 'neighbor_id'],
        output_file='bright_neighbor_results.xlsx'
    )
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# Number of results: 734
# INFO: Query finished. [astroquery.utils.tap.core]
# Number of results: 717
# INFO: Query finished. [astroquery.utils.tap.core]
# Number of results: 17

# %% [markdown]
# ### but now switch to filtering the ones in merged_df

# %%
merged_df = pd.read_excel('../../results/combined_query_with_mass_detection_limit.xlsx', dtype={'source_id': str, 'source_id_dr2': str, 'source_id_dr3': str, 'HIP Number': str})

# merged_df = pd.read_excel('../../results/combined_query_with_mass_detection_limit.xlsx', dtype={'source_id': str, 'source_id_dr2': str, 'source_id_dr3': str, 'HIP Number': str}).iloc[20:30]
merged_df
# Out:
#                 source_id        source_id_dr2        source_id_dr3  \
# 0       22269508511466624    22269508511466624    22269508511466624
# 1     1173206811240350592  1173206811240350592  1173206811240350592
# 2     6349915534307041152  6349915534307041152  6349915534307041152
# 3     2683023811628007296  2683023811628007296  2683023811628007296
# 4     3919427007885527680  3919427007885527680  3919427007885527680
# ...                   ...                  ...                  ...
# 4504  4762394397915837056  4762394397915837056  4762394397915837056
# 4505  6323603052822806784  6323603052822806784                  NaN
# 4506  6536790454707565696  6536790454707565696                  NaN
# 4507  1273169013960272640  1273169013960272640  1273169013960272640
# 4508  4299567450800546304  4299567450800546304  4299567450800546304
#
#               RA        DEC      V_mag  Phot G Mean Mag  Phot BP Mean Mag  \
# 0      41.482248  10.666519  12.687016        11.891757         12.940540
# 1     221.961398   7.416476  11.617188        10.907482         11.867918
# 2     312.940241 -79.315480  11.810019        10.907413         12.067825
# 3     330.540802   1.398992   9.136045         8.403359          9.387209
# 4     179.383579  11.828810  11.797612        10.899825         12.055270
# ...          ...        ...        ...              ...               ...
# 4504   73.721844 -58.547353   6.005004         6.005004          6.222638
# 4505  219.245202 -12.303777   6.062907         6.062907          6.331566
# 4506  350.491302 -40.174354   9.840427         9.840427         10.085142
# 4507  234.223073  29.990933   6.356777         6.356777          6.567007
# 4508  301.960094   9.399971   6.436103         6.436103          6.637836
#
#       Phot RP Mean Mag     BP-RP  ...  Radius [R_Sun]  HZ_limit [AU]  \
# 0            10.878490  2.062050  ...        0.659257       0.259182
# 1             9.918146  1.949772  ...        0.872650       0.343274
# 2             9.833761  2.234064  ...        0.367781       0.144694
# 3             7.420015  1.967194  ...        0.702667       0.276365
# 4             9.827121  2.228149  ...        0.548498       0.217990
# ...                ...       ...  ...             ...            ...
# 4504          5.630950  0.591688  ...        1.241460       1.536463
# 4505          5.721863  0.609704  ...        1.127712       1.316431
# 4506          9.426617  0.658525  ...        1.350000       1.512488
# 4507          5.985064  0.581943  ...        1.303444       1.529632
# 4508          6.073288  0.564548  ...        1.307444       1.596606
#
#       RV precision [m/s]  HZ Detection Limit [M_Earth]  Spectral Type  \
# 0               0.912258                      3.888545              M
# 1               0.557978                      2.912921              M
# 2               0.610223                      1.535877              M
# 3               0.178149                      0.795958              M
# 4               0.608185                      2.008597              M
# ...                  ...                           ...            ...
# 4504            1.795406                     28.367441              F
# 4505            1.844249                     26.984210              B
# 4506           10.696199                    167.778821            NaN
# 4507            2.247971                     34.867299              F
# 4508            2.589273                     41.904427              F
#
#        HD Number  GJ Number  HIP Number Object Type  \
# 0            NaN        NaN         NaN     HighPM*
# 1            NaN        NaN         NaN     HighPM*
# 2            NaN     GJ 808         NaN     HighPM*
# 3      HD 209290     GJ 846      108782     HighPM*
# 4            NaN    GJ 3695       58321     HighPM*
# ...          ...        ...         ...         ...
# 4504   HD  31746        NaN       22844     HighPM*
# 4505   HD 128429        NaN       71469     HighPM*
# 4506         NaN        NaN         NaN         NaN
# 4507   HD 139389        NaN       76456     HighPM*
# 4508  HD 191104A        NaN         NaN     HighPM*
#
#      HZ Detection Limit Simplified [M_Earth]
# 0                                   3.888505
# 1                                   2.912901
# 2                                   1.535867
# 3                                   0.795956
# 4                                   2.008582
# ...                                      ...
# 4504                               28.366511
# 4505                               26.983369
# 4506                              167.746334
# 4507                               34.865848
# 4508                               41.902417
#
# [4509 rows x 24 columns]

# %%
import pandas as pd
from astroquery.gaia import Gaia
import time

# Parameters
NEIGHBOR_G_MAG_LIMIT = 14  # Example brightness limit for neighbors
SEARCH_RADIUS = 2 / 3600.0  # 2 arcseconds in degrees

# Function to create a query for nearby stars
def create_neighbor_query(source_id, ra, dec, neighbor_g_mag_limit, search_radius):
    query = f"""
    SELECT 
        source_id, ra, dec, phot_g_mean_mag
    FROM 
        gaiadr2.gaia_source
    WHERE 
        1=CONTAINS(
            POINT('ICRS', {ra}, {dec}),
            CIRCLE('ICRS', ra, dec, {search_radius})
        )
        AND phot_g_mean_mag < {neighbor_g_mag_limit}
        AND source_id != {source_id}
    """
    return query

# DataFrames: merged_df (input sources)
rows_with_bright_neighbors = []
rows_without_bright_neighbors = []

# Iterate through each row in merged_df
for i, row in merged_df.iterrows():
    print(i, row['source_id_dr2'])
    # Create a query for the current source
    query = create_neighbor_query(
        source_id=row['source_id_dr2'],
        ra=row['RA'],
        dec=row['DEC'],
        neighbor_g_mag_limit=NEIGHBOR_G_MAG_LIMIT,
        search_radius=SEARCH_RADIUS
    )
    
    # Execute the query
    neighbors_df = execute_gaia_query(query)
    
    # Check if bright neighbors exist
    if neighbors_df is not None and not neighbors_df.empty:
        # Add the row to the bright neighbors list
        rows_with_bright_neighbors.append(row)
    else:
        # Add the row to the no bright neighbors list
        rows_without_bright_neighbors.append(row)

# Create DataFrames for rows with and without bright neighbors
bright_neighbors_df = pd.DataFrame(rows_with_bright_neighbors)
rows_without_bright_neighbors_df = pd.DataFrame(rows_without_bright_neighbors)

# Output the results
print(f"Rows with bright neighbors: {len(bright_neighbors_df)}")
print(f"Rows without bright neighbors: {len(rows_without_bright_neighbors_df)}")
# Out:
# 0 22269508511466624
# INFO: Query finished. [astroquery.utils.tap.core]
# 1 1173206811240350592
# INFO: Query finished. [astroquery.utils.tap.core]
# 2 6349915534307041152
# INFO: Query finished. [astroquery.utils.tap.core]
# 3 2683023811628007296
# INFO: Query finished. [astroquery.utils.tap.core]
# 4 3919427007885527680
# INFO: Query finished. [astroquery.utils.tap.core]
# 5 4595398441587270272
# INFO: Query finished. [astroquery.utils.tap.core]
# 6 4188969431580611456
# INFO: Query finished. [astroquery.utils.tap.core]
# 7 5702187702467261696
# INFO: Query finished. [astroquery.utils.tap.core]
# 8 3903318372263850368
# INFO: Query finished. [astroquery.utils.tap.core]
# 9 4975284381905517824
# INFO: Query finished. [astroquery.utils.tap.core]
# 10 5970137861534914304
# INFO: Query finished. [astroquery.utils.tap.core]
# 11 5946986063684477056
# INFO: Query finished. [astroquery.utils.tap.core]
# 12 3828238392559860992
# INFO: Query finished. [astroquery.utils.tap.core]
# 13 1450067137649449728
# INFO: Query finished. [astroquery.utils.tap.core]
# 14 6164134146938406144
# INFO: Query finished. [astroquery.utils.tap.core]
# 15 102648588798884736
# INFO: Query finished. [astroquery.utils.tap.core]
# 16 689295212526177024
# INFO: Query finished. [astroquery.utils.tap.core]
# 17 6293916376311538944
# INFO: Query finished. [astroquery.utils.tap.core]
# 18 3536123338748976256
# INFO: Query finished. [astroquery.utils.tap.core]
# 19 4227888840368754432
# INFO: Query finished. [astroquery.utils.tap.core]
# 20 5373804364262422144
# INFO: Query finished. [astroquery.utils.tap.core]
# 21 2814501281775322240
# INFO: Query finished. [astroquery.utils.tap.core]
# 22 5746229289255499776
# INFO: Query finished. [astroquery.utils.tap.core]
# 23 3093380483331664896
# INFO: Query finished. [astroquery.utils.tap.core]
# 24 4002350285065884032
# INFO: Query finished. [astroquery.utils.tap.core]
# 25 6189329043571426944
# INFO: Query finished. [astroquery.utils.tap.core]
# 26 5616120681034800000
# INFO: Query finished. [astroquery.utils.tap.core]
# 27 14560046508208640
# INFO: Query finished. [astroquery.utils.tap.core]
# 28 4432655774190464896
# INFO: Query finished. [astroquery.utils.tap.core]
# 29 6348514275456913792
# INFO: Query finished. [astroquery.utils.tap.core]
# 30 2789773986820056064
# INFO: Query finished. [astroquery.utils.tap.core]
# 31 3767878708888402816
# INFO: Query finished. [astroquery.utils.tap.core]
# 32 3445879616230046720
# INFO: Query finished. [astroquery.utils.tap.core]
# 33 4364480521350598144
# INFO: Query finished. [astroquery.utils.tap.core]
# 34 6766734242006157568
# INFO: Query finished. [astroquery.utils.tap.core]
# 35 672091364541849344
# INFO: Query finished. [astroquery.utils.tap.core]
# 36 3323536751251359104
# INFO: Query finished. [astroquery.utils.tap.core]
# 37 6304598131775309056
# INFO: Query finished. [astroquery.utils.tap.core]
# 38 2428541639221790848
# INFO: Query finished. [astroquery.utils.tap.core]
# 39 2725934142688500352
# INFO: Query finished. [astroquery.utils.tap.core]
# 40 2752746111688997248
# INFO: Query finished. [astroquery.utils.tap.core]
# 41 6220074790298993664
# INFO: Query finished. [astroquery.utils.tap.core]
# 42 2798766647610195456
# INFO: Query finished. [astroquery.utils.tap.core]
# 43 4850894569872086528
# INFO: Query finished. [astroquery.utils.tap.core]
# 44 2364492097606462336
# INFO: Query finished. [astroquery.utils.tap.core]
# 45 614543647497149056
# INFO: Query finished. [astroquery.utils.tap.core]
# 46 6268621389764361344
# INFO: Query finished. [astroquery.utils.tap.core]
# 47 43335537119008896
# INFO: Query finished. [astroquery.utils.tap.core]
# 48 5143621433184275200
# INFO: Query finished. [astroquery.utils.tap.core]
# 49 2962658549474035584
# INFO: Query finished. [astroquery.utils.tap.core]
# 50 2556424771496343424
# INFO: Query finished. [astroquery.utils.tap.core]
# 51 4915139584039259392
# INFO: Query finished. [astroquery.utils.tap.core]
# 52 6253785473213599360
# INFO: Query finished. [astroquery.utils.tap.core]
# 53 4496250461589918080
# INFO: Query finished. [astroquery.utils.tap.core]
# 54 26283932836820096
# INFO: Query finished. [astroquery.utils.tap.core]
# 55 3795389692406967424
# INFO: Query finished. [astroquery.utils.tap.core]
# 56 4955395178633330304
# INFO: Query finished. [astroquery.utils.tap.core]
# 57 89630989600475904
# INFO: Query finished. [astroquery.utils.tap.core]
# 58 5357824955628443776
# INFO: Query finished. [astroquery.utils.tap.core]
# 59 5217826648313337856
# INFO: Query finished. [astroquery.utils.tap.core]
# 60 111379432679196672
# INFO: Query finished. [astroquery.utils.tap.core]
# 61 2383999392388000640
# INFO: Query finished. [astroquery.utils.tap.core]
# 62 3380787325274157824
# INFO: Query finished. [astroquery.utils.tap.core]
# 63 4279492361332301056
# INFO: Query finished. [astroquery.utils.tap.core]
# 64 3478160727866058368
# INFO: Query finished. [astroquery.utils.tap.core]
# 65 5924187617032756736
# INFO: Query finished. [astroquery.utils.tap.core]
# 66 3460347849221303296
# INFO: Query finished. [astroquery.utils.tap.core]
# 67 3847645013308140800
# INFO: Query finished. [astroquery.utils.tap.core]
# 68 6885776098199761024
# INFO: Query finished. [astroquery.utils.tap.core]
# 69 5956746565858482176
# INFO: Query finished. [astroquery.utils.tap.core]
# 70 3219132482897057152
# INFO: Query finished. [astroquery.utils.tap.core]
# 71 4922358908667577728
# INFO: Query finished. [astroquery.utils.tap.core]
# 72 6673000841376349696
# INFO: Query finished. [astroquery.utils.tap.core]
# 73 2856828523778894592
# INFO: Query finished. [astroquery.utils.tap.core]
# 74 2525688198820543360
# INFO: Query finished. [astroquery.utils.tap.core]
# 75 678247633227151872
# INFO: Query finished. [astroquery.utils.tap.core]
# 76 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 77 3413567782690754688
# INFO: Query finished. [astroquery.utils.tap.core]
# 78 2410173541565153920
# INFO: Query finished. [astroquery.utils.tap.core]
# 79 2708264509793292544
# INFO: Query finished. [astroquery.utils.tap.core]
# 80 3591874007115486208
# INFO: Query finished. [astroquery.utils.tap.core]
# 81 3383405537340380416
# INFO: Query finished. [astroquery.utils.tap.core]
# 82 2724890053318383232
# INFO: Query finished. [astroquery.utils.tap.core]
# 83 6731849418125307904
# INFO: Query finished. [astroquery.utils.tap.core]
# 84 4457688286699977344
# INFO: Query finished. [astroquery.utils.tap.core]
# 85 5059643105878789632
# INFO: Query finished. [astroquery.utils.tap.core]
# 86 5891544873500692608
# INFO: Query finished. [astroquery.utils.tap.core]
# 87 3231945508509506176
# INFO: Query finished. [astroquery.utils.tap.core]
# 88 1231492609823304320
# INFO: Query finished. [astroquery.utils.tap.core]
# 89 1231492609822865152
# INFO: Query finished. [astroquery.utils.tap.core]
# 90 4002440548098640896
# INFO: Query finished. [astroquery.utils.tap.core]
# 91 4448223656247483904
# INFO: Query finished. [astroquery.utils.tap.core]
# 92 4477295014267164800
# INFO: Query finished. [astroquery.utils.tap.core]
# 93 6259717372800655872
# INFO: Query finished. [astroquery.utils.tap.core]
# 94 3013932242712946688
# INFO: Query finished. [astroquery.utils.tap.core]
# 95 3046530292874936448
# INFO: Query finished. [astroquery.utils.tap.core]
# 96 1234756368356786560
# INFO: Query finished. [astroquery.utils.tap.core]
# 97 3293037741802934784
# INFO: Query finished. [astroquery.utils.tap.core]
# 98 36540074223000576
# INFO: Query finished. [astroquery.utils.tap.core]
# 99 3969885761146749952
# INFO: Query finished. [astroquery.utils.tap.core]
# 100 6769835655073839232
# INFO: Query finished. [astroquery.utils.tap.core]
# 101 4799648080951525120
# INFO: Query finished. [astroquery.utils.tap.core]
# 102 4134107168607042816
# INFO: Query finished. [astroquery.utils.tap.core]
# 103 4347870370990204928
# INFO: Query finished. [astroquery.utils.tap.core]
# 104 4946938113149426944
# INFO: Query finished. [astroquery.utils.tap.core]
# 105 5271611183731282304
# INFO: Query finished. [astroquery.utils.tap.core]
# 106 6882393725554653056
# INFO: Query finished. [astroquery.utils.tap.core]
# 107 5718332793774528896
# INFO: Query finished. [astroquery.utils.tap.core]
# 108 4568345164145035776
# INFO: Query finished. [astroquery.utils.tap.core]
# 109 4268226078065241600
# INFO: Query finished. [astroquery.utils.tap.core]
# 110 3922653662195500928
# INFO: Query finished. [astroquery.utils.tap.core]
# 111 6232175602956919168
# INFO: Query finished. [astroquery.utils.tap.core]
# 112 2823131829578270080
# INFO: Query finished. [astroquery.utils.tap.core]
# 113 6611034114084586368
# INFO: Query finished. [astroquery.utils.tap.core]
# 114 6124711741640147712
# INFO: Query finished. [astroquery.utils.tap.core]
# 115 4177731838628465408
# INFO: Query finished. [astroquery.utils.tap.core]
# 116 3980045523465047168
# INFO: Query finished. [astroquery.utils.tap.core]
# 117 2515037264041041536
# INFO: Query finished. [astroquery.utils.tap.core]
# 118 6915227165689394048
# INFO: Query finished. [astroquery.utils.tap.core]
# 119 3562655997435621120
# INFO: Query finished. [astroquery.utils.tap.core]
# 120 3741297293732404352
# INFO: Query finished. [astroquery.utils.tap.core]
# 121 3547944531854903168
# INFO: Query finished. [astroquery.utils.tap.core]
# 122 4414858219987352320
# INFO: Query finished. [astroquery.utils.tap.core]
# 123 3599411399842474368
# INFO: Query finished. [astroquery.utils.tap.core]
# 124 3832057786716848512
# INFO: Query finished. [astroquery.utils.tap.core]
# 125 4540061704988054400
# INFO: Query finished. [astroquery.utils.tap.core]
# 126 4857423676076142720
# INFO: Query finished. [astroquery.utils.tap.core]
# 127 3357701803041885696
# INFO: Query finished. [astroquery.utils.tap.core]
# 128 5021412261945549568
# INFO: Query finished. [astroquery.utils.tap.core]
# 129 3908605030329021440
# INFO: Query finished. [astroquery.utils.tap.core]
# 130 4008237753220479488
# INFO: Query finished. [astroquery.utils.tap.core]
# 131 43335880716390784
# INFO: Query finished. [astroquery.utils.tap.core]
# 132 5488228615216198528
# INFO: Query finished. [astroquery.utils.tap.core]
# 133 6311730801143986688
# INFO: Query finished. [astroquery.utils.tap.core]
# 134 3843330735839291648
# INFO: Query finished. [astroquery.utils.tap.core]
# 135 4550763526539955712
# INFO: Query finished. [astroquery.utils.tap.core]
# 136 3980560507224374400
# INFO: Query finished. [astroquery.utils.tap.core]
# 137 4654969496256092032
# INFO: Query finished. [astroquery.utils.tap.core]
# 138 2711324381934051200
# INFO: Query finished. [astroquery.utils.tap.core]
# 139 3686261307923490688
# INFO: Query finished. [astroquery.utils.tap.core]
# 140 3771533721761978496
# INFO: Query finished. [astroquery.utils.tap.core]
# 141 103363168277756928
# INFO: Query finished. [astroquery.utils.tap.core]
# 142 3238437574916370048
# INFO: Query finished. [astroquery.utils.tap.core]
# 143 2717105133036645760
# INFO: Query finished. [astroquery.utils.tap.core]
# 144 2362062417427288832
# INFO: Query finished. [astroquery.utils.tap.core]
# 145 2414454387009212416
# INFO: Query finished. [astroquery.utils.tap.core]
# 146 3657653114880309248
# INFO: Query finished. [astroquery.utils.tap.core]
# 147 6603415602311189888
# INFO: Query finished. [astroquery.utils.tap.core]
# 148 3131514462863888768
# INFO: Query finished. [astroquery.utils.tap.core]
# 149 4399508144313704960
# INFO: Query finished. [astroquery.utils.tap.core]
# 150 5006921282807193856
# INFO: Query finished. [astroquery.utils.tap.core]
# 151 6080301367488384896
# INFO: Query finished. [astroquery.utils.tap.core]
# 152 5704545811310308480
# INFO: Query finished. [astroquery.utils.tap.core]
# 153 3988689609004982912
# INFO: Query finished. [astroquery.utils.tap.core]
# 154 865699110037321600
# INFO: Query finished. [astroquery.utils.tap.core]
# 155 3969885761146749824
# INFO: Query finished. [astroquery.utils.tap.core]
# 156 5144740907820131840
# INFO: Query finished. [astroquery.utils.tap.core]
# 157 6637963425890391552
# INFO: Query finished. [astroquery.utils.tap.core]
# 158 2713570954772828544
# INFO: Query finished. [astroquery.utils.tap.core]
# 159 5084210589392620032
# INFO: Query finished. [astroquery.utils.tap.core]
# 160 4960362080676620160
# INFO: Query finished. [astroquery.utils.tap.core]
# 161 2830099469122381056
# INFO: Query finished. [astroquery.utils.tap.core]
# 162 2905039359877623808
# INFO: Query finished. [astroquery.utils.tap.core]
# 163 2761162254723511424
# INFO: Query finished. [astroquery.utils.tap.core]
# 164 3914019231742221568
# INFO: Query finished. [astroquery.utils.tap.core]
# 165 5061036084033386624
# INFO: Query finished. [astroquery.utils.tap.core]
# 166 6631770869026896512
# INFO: Query finished. [astroquery.utils.tap.core]
# 167 2823509855420318720
# INFO: Query finished. [astroquery.utils.tap.core]
# 168 2625819417091105152
# INFO: Query finished. [astroquery.utils.tap.core]
# 169 4926529081393983104
# INFO: Query finished. [astroquery.utils.tap.core]
# 170 1171574685013520640
# INFO: Query finished. [astroquery.utils.tap.core]
# 171 5863130980814698112
# INFO: Query finished. [astroquery.utils.tap.core]
# 172 70051608089857536
# INFO: Query finished. [astroquery.utils.tap.core]
# 173 5291028284195365632
# INFO: Query finished. [astroquery.utils.tap.core]
# 174 3134548741299795968
# INFO: Query finished. [astroquery.utils.tap.core]
# 175 2544337393496946304
# INFO: Query finished. [astroquery.utils.tap.core]
# 176 3738099879558957952
# INFO: Query finished. [astroquery.utils.tap.core]
# 177 6504705571539380992
# INFO: Query finished. [astroquery.utils.tap.core]
# 178 4743944588505676672
# INFO: Query finished. [astroquery.utils.tap.core]
# 179 4725765233188275200
# INFO: Query finished. [astroquery.utils.tap.core]
# 180 623617156751323776
# INFO: Query finished. [astroquery.utils.tap.core]
# 181 4751066576291557632
# INFO: Query finished. [astroquery.utils.tap.core]
# 182 5587451911768090880
# INFO: Query finished. [astroquery.utils.tap.core]
# 183 2350654434533221248
# INFO: Query finished. [astroquery.utils.tap.core]
# 184 3165304692865336832
# INFO: Query finished. [astroquery.utils.tap.core]
# 185 3255968634985106816
# INFO: Query finished. [astroquery.utils.tap.core]
# 186 5203415177608975616
# INFO: Query finished. [astroquery.utils.tap.core]
# 187 5203415177605909504
# INFO: Query finished. [astroquery.utils.tap.core]
# 188 2517883830925784704
# INFO: Query finished. [astroquery.utils.tap.core]
# 189 1896408724688348928
# INFO: Query finished. [astroquery.utils.tap.core]
# 190 4880837088995421952
# INFO: Query finished. [astroquery.utils.tap.core]
# 191 116261779701601152
# INFO: Query finished. [astroquery.utils.tap.core]
# 192 5067008970494311936
# INFO: Query finished. [astroquery.utils.tap.core]
# 193 4274925505435880704
# INFO: Query finished. [astroquery.utils.tap.core]
# 194 301785537751949824
# INFO: Query finished. [astroquery.utils.tap.core]
# 195 6034755850675869312
# INFO: Query finished. [astroquery.utils.tap.core]
# 196 2814379579582643328
# INFO: Query finished. [astroquery.utils.tap.core]
# 197 2885863400349980288
# INFO: Query finished. [astroquery.utils.tap.core]
# 198 1158503591997923072
# INFO: Query finished. [astroquery.utils.tap.core]
# 199 6690456619260897792
# INFO: Query finished. [astroquery.utils.tap.core]
# 200 3623225378590595072
# INFO: Query finished. [astroquery.utils.tap.core]
# 201 4282578724832056576
# INFO: Query finished. [astroquery.utils.tap.core]
# 202 3978910415148365696
# INFO: Query finished. [astroquery.utils.tap.core]
# 203 117990177621007744
# INFO: Query finished. [astroquery.utils.tap.core]
# 204 1183850942790617856
# INFO: Query finished. [astroquery.utils.tap.core]
# 205 6643046944883125376
# INFO: Query finished. [astroquery.utils.tap.core]
# 206 4344429586787123072
# INFO: Query finished. [astroquery.utils.tap.core]
# 207 1178287203500006656
# INFO: Query finished. [astroquery.utils.tap.core]
# 208 4925565806128845056
# INFO: Query finished. [astroquery.utils.tap.core]
# 209 6228000276276576896
# INFO: Query finished. [astroquery.utils.tap.core]
# 210 5837746491063380352
# INFO: Query finished. [astroquery.utils.tap.core]
# 211 2343064127808964224
# INFO: Query finished. [astroquery.utils.tap.core]
# 212 4309961232989305600
# INFO: Query finished. [astroquery.utils.tap.core]
# 213 5744597549575864064
# INFO: Query finished. [astroquery.utils.tap.core]
# 214 1229977414080680192
# INFO: Query finished. [astroquery.utils.tap.core]
# 215 4509134263972556288
# INFO: Query finished. [astroquery.utils.tap.core]
# 216 4857921102008397824
# INFO: Query finished. [astroquery.utils.tap.core]
# 217 3028714046982751872
# INFO: Query finished. [astroquery.utils.tap.core]
# 218 2758686773014648320
# INFO: Query finished. [astroquery.utils.tap.core]
# 219 2741901697224268928
# INFO: Query finished. [astroquery.utils.tap.core]
# 220 4356712162461401728
# INFO: Query finished. [astroquery.utils.tap.core]
# 221 3304831550199371392
# INFO: Query finished. [astroquery.utils.tap.core]
# 222 5079592851010222336
# INFO: Query finished. [astroquery.utils.tap.core]
# 223 5473349302315731072
# INFO: Query finished. [astroquery.utils.tap.core]
# 224 3795594270288562304
# INFO: Query finished. [astroquery.utils.tap.core]
# 225 3554395813252625920
# INFO: Query finished. [astroquery.utils.tap.core]
# 226 5254819339117709952
# INFO: Query finished. [astroquery.utils.tap.core]
# 227 3936909723803146496
# INFO: Query finished. [astroquery.utils.tap.core]
# 228 5162123155863791744
# INFO: Query finished. [astroquery.utils.tap.core]
# 229 5476589734884246528
# INFO: Query finished. [astroquery.utils.tap.core]
# 230 2836968977254848384
# INFO: Query finished. [astroquery.utils.tap.core]
# 231 6099000589942631424
# INFO: Query finished. [astroquery.utils.tap.core]
# 232 5444096348779619712
# INFO: Query finished. [astroquery.utils.tap.core]
# 233 6514632718428652928
# INFO: Query finished. [astroquery.utils.tap.core]
# 234 3828751074215823872
# INFO: Query finished. [astroquery.utils.tap.core]
# 235 2722233427067408640
# INFO: Query finished. [astroquery.utils.tap.core]
# 236 3972476416700318336
# INFO: Query finished. [astroquery.utils.tap.core]
# 237 6155259541913716608
# INFO: Query finished. [astroquery.utils.tap.core]
# 238 5563375081015174656
# INFO: Query finished. [astroquery.utils.tap.core]
# 239 3028661201708084096
# INFO: Query finished. [astroquery.utils.tap.core]
# 240 3407150556091924736
# INFO: Query finished. [astroquery.utils.tap.core]
# 241 6258382634409906560
# INFO: Query finished. [astroquery.utils.tap.core]
# 242 5768348787444739712
# INFO: Query finished. [astroquery.utils.tap.core]
# 243 5046897017332803584
# INFO: Query finished. [astroquery.utils.tap.core]
# 244 2687557579106621824
# INFO: Query finished. [astroquery.utils.tap.core]
# 245 3359074685047632640
# INFO: Query finished. [astroquery.utils.tap.core]
# 246 2421439481301400960
# INFO: Query finished. [astroquery.utils.tap.core]
# 247 12828899809609856
# INFO: Query finished. [astroquery.utils.tap.core]
# 248 12828899810152704
# INFO: Query finished. [astroquery.utils.tap.core]
# 249 4676145235498113280
# INFO: Query finished. [astroquery.utils.tap.core]
# 250 6143992296510398208
# INFO: Query finished. [astroquery.utils.tap.core]
# 251 4389844948935164544
# INFO: Query finished. [astroquery.utils.tap.core]
# 252 6155176150828569088
# INFO: Query finished. [astroquery.utils.tap.core]
# 253 6633015859784740224
# INFO: Query finished. [astroquery.utils.tap.core]
# 254 6179672032944816000
# INFO: Query finished. [astroquery.utils.tap.core]
# 255 2386898972054841088
# INFO: Query finished. [astroquery.utils.tap.core]
# 256 4917782741272766592
# INFO: Query finished. [astroquery.utils.tap.core]
# 257 681999884156922368
# INFO: Query finished. [astroquery.utils.tap.core]
# 258 3607945912174970880
# INFO: Query finished. [astroquery.utils.tap.core]
# 259 1800808220175220480
# INFO: Query finished. [astroquery.utils.tap.core]
# 260 5891458149515680128
# INFO: Query finished. [astroquery.utils.tap.core]
# 261 5271149079609264000
# INFO: Query finished. [astroquery.utils.tap.core]
# 262 6736232346363422336
# INFO: Query finished. [astroquery.utils.tap.core]
# 263 4072260704719970944
# INFO: Query finished. [astroquery.utils.tap.core]
# 264 4137734865485308800
# INFO: Query finished. [astroquery.utils.tap.core]
# 265 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 266 6516241956775652224
# INFO: Query finished. [astroquery.utils.tap.core]
# 267 6167520539672727424
# INFO: Query finished. [astroquery.utils.tap.core]
# 268 6873346153611014016
# INFO: Query finished. [astroquery.utils.tap.core]
# 269 1156846524895814144
# INFO: Query finished. [astroquery.utils.tap.core]
# 270 6628904068549598080
# INFO: Query finished. [astroquery.utils.tap.core]
# 271 5669747402161003520
# INFO: Query finished. [astroquery.utils.tap.core]
# 272 5497072086021346688
# INFO: Query finished. [astroquery.utils.tap.core]
# 273 4510987662629223424
# INFO: Query finished. [astroquery.utils.tap.core]
# 274 4310095515150736512
# INFO: Query finished. [astroquery.utils.tap.core]
# 275 2807539376010425728
# INFO: Query finished. [astroquery.utils.tap.core]
# 276 3239798461074336640
# INFO: Query finished. [astroquery.utils.tap.core]
# 277 5067164968002367872
# INFO: Query finished. [astroquery.utils.tap.core]
# 278 3029689554311211264
# INFO: Query finished. [astroquery.utils.tap.core]
# 279 3005681889712375552
# INFO: Query finished. [astroquery.utils.tap.core]
# 280 1222160745406471680
# INFO: Query finished. [astroquery.utils.tap.core]
# 281 3877784615594763776
# INFO: Query finished. [astroquery.utils.tap.core]
# 282 1876551957008238208
# INFO: Query finished. [astroquery.utils.tap.core]
# 283 5526688776047957504
# INFO: Query finished. [astroquery.utils.tap.core]
# 284 3340966243931480064
# INFO: Query finished. [astroquery.utils.tap.core]
# 285 685113121267456896
# INFO: Query finished. [astroquery.utils.tap.core]
# 286 3238221658320206208
# INFO: Query finished. [astroquery.utils.tap.core]
# 287 4009947704255866752
# INFO: Query finished. [astroquery.utils.tap.core]
# 288 4230094705509739904
# INFO: Query finished. [astroquery.utils.tap.core]
# 289 3836586468953204608
# INFO: Query finished. [astroquery.utils.tap.core]
# 290 4161254832282736384
# INFO: Query finished. [astroquery.utils.tap.core]
# 291 2541200830419126016
# INFO: Query finished. [astroquery.utils.tap.core]
# 292 3312751229374292864
# INFO: Query finished. [astroquery.utils.tap.core]
# 293 4173377841310889088
# INFO: Query finished. [astroquery.utils.tap.core]
# 294 2561679986105169536
# INFO: Query finished. [astroquery.utils.tap.core]
# 295 6062166950418030336
# INFO: Query finished. [astroquery.utils.tap.core]
# 296 128685947561889920
# INFO: Query finished. [astroquery.utils.tap.core]
# 297 5549877162737152640
# INFO: Query finished. [astroquery.utils.tap.core]
# 298 2611163717366876544
# INFO: Query finished. [astroquery.utils.tap.core]
# 299 4952663888670428800
# INFO: Query finished. [astroquery.utils.tap.core]
# 300 2738145555048846080
# INFO: Query finished. [astroquery.utils.tap.core]
# 301 6673307841343417856
# INFO: Query finished. [astroquery.utils.tap.core]
# 302 3552000252294347392
# INFO: Query finished. [astroquery.utils.tap.core]
# 303 4778404524166628480
# INFO: Query finished. [astroquery.utils.tap.core]
# 304 3296932482569720192
# INFO: Query finished. [astroquery.utils.tap.core]
# 305 6030989542329090816
# INFO: Query finished. [astroquery.utils.tap.core]
# 306 6118597868578772352
# INFO: Query finished. [astroquery.utils.tap.core]
# 307 3292437236655180672
# INFO: Query finished. [astroquery.utils.tap.core]
# 308 2409310631095904896
# INFO: Query finished. [astroquery.utils.tap.core]
# 309 5773395408375821056
# INFO: Query finished. [astroquery.utils.tap.core]
# 310 2428162410789155328
# INFO: Query finished. [astroquery.utils.tap.core]
# 311 3869563017398270720
# INFO: Query finished. [astroquery.utils.tap.core]
# 312 2772804845911842944
# INFO: Query finished. [astroquery.utils.tap.core]
# 313 2798587122272590080
# INFO: Query finished. [astroquery.utils.tap.core]
# 314 117654650480415744
# INFO: Query finished. [astroquery.utils.tap.core]
# 315 2432574269914995200
# INFO: Query finished. [astroquery.utils.tap.core]
# 316 3689602277083844480
# INFO: Query finished. [astroquery.utils.tap.core]
# 317 5334356223546958464
# INFO: Query finished. [astroquery.utils.tap.core]
# 318 5977814720499134720
# INFO: Query finished. [astroquery.utils.tap.core]
# 319 5521994754757300224
# INFO: Query finished. [astroquery.utils.tap.core]
# 320 1244644727396803584
# INFO: Query finished. [astroquery.utils.tap.core]
# 321 3060332221821297408
# INFO: Query finished. [astroquery.utils.tap.core]
# 322 2705787825492130304
# INFO: Query finished. [astroquery.utils.tap.core]
# 323 3553233526383181184
# INFO: Query finished. [astroquery.utils.tap.core]
# 324 1826261983123386240
# INFO: Query finished. [astroquery.utils.tap.core]
# 325 4047088313729864192
# INFO: Query finished. [astroquery.utils.tap.core]
# 326 6840822904599511936
# INFO: Query finished. [astroquery.utils.tap.core]
# 327 6717432239396780544
# INFO: Query finished. [astroquery.utils.tap.core]
# 328 6293217116979986560
# INFO: Query finished. [astroquery.utils.tap.core]
# 329 6226702921268202880
# INFO: Query finished. [astroquery.utils.tap.core]
# 330 2023209048496665728
# INFO: Query finished. [astroquery.utils.tap.core]
# 331 2018822443789422720
# INFO: Query finished. [astroquery.utils.tap.core]
# 332 4472382946069723648
# INFO: Query finished. [astroquery.utils.tap.core]
# 333 2035957434815627008
# INFO: Query finished. [astroquery.utils.tap.core]
# 334 3288413676933442432
# INFO: Query finished. [astroquery.utils.tap.core]
# 335 116037371954842240
# INFO: Query finished. [astroquery.utils.tap.core]
# 336 92102618725254912
# INFO: Query finished. [astroquery.utils.tap.core]
# 337 887456658443952256
# INFO: Query finished. [astroquery.utils.tap.core]
# 338 2897805299218977152
# INFO: Query finished. [astroquery.utils.tap.core]
# 339 122518310101463808
# INFO: Query finished. [astroquery.utils.tap.core]
# 340 3933777077736204544
# INFO: Query finished. [astroquery.utils.tap.core]
# 341 3218624650260845952
# INFO: Query finished. [astroquery.utils.tap.core]
# 342 1892539307048908928
# INFO: Query finished. [astroquery.utils.tap.core]
# 343 3934530861677044992
# INFO: Query finished. [astroquery.utils.tap.core]
# 344 3141719786195912320
# INFO: Query finished. [astroquery.utils.tap.core]
# 345 6262941342755502208
# INFO: Query finished. [astroquery.utils.tap.core]
# 346 4566542068153691904
# INFO: Query finished. [astroquery.utils.tap.core]
# 347 2040475607275354880
# INFO: Query finished. [astroquery.utils.tap.core]
# 348 4833654227548585856
# INFO: Query finished. [astroquery.utils.tap.core]
# 349 1225075997402563840
# INFO: Query finished. [astroquery.utils.tap.core]
# 350 3584121041391180544
# INFO: Query finished. [astroquery.utils.tap.core]
# 351 3975087310139804800
# INFO: Query finished. [astroquery.utils.tap.core]
# 352 3561574971346845440
# INFO: Query finished. [astroquery.utils.tap.core]
# 353 6832480291404495360
# INFO: Query finished. [astroquery.utils.tap.core]
# 354 6051948158061617024
# INFO: Query finished. [astroquery.utils.tap.core]
# 355 3829146451725169920
# INFO: Query finished. [astroquery.utils.tap.core]
# 356 6806196672101182720
# INFO: Query finished. [astroquery.utils.tap.core]
# 357 5172403555223128576
# INFO: Query finished. [astroquery.utils.tap.core]
# 358 4984184825454337408
# INFO: Query finished. [astroquery.utils.tap.core]
# 359 3800590554204451712
# INFO: Query finished. [astroquery.utils.tap.core]
# 360 6467586746180725248
# INFO: Query finished. [astroquery.utils.tap.core]
# 361 1264654395913772416
# INFO: Query finished. [astroquery.utils.tap.core]
# 362 2384877214983800448
# INFO: Query finished. [astroquery.utils.tap.core]
# 363 4223848757911010816
# INFO: Query finished. [astroquery.utils.tap.core]
# 364 3347826784173590656
# INFO: Query finished. [astroquery.utils.tap.core]
# 365 3847123707357532672
# INFO: Query finished. [astroquery.utils.tap.core]
# 366 2307558595246087936
# INFO: Query finished. [astroquery.utils.tap.core]
# 367 2604197860232993024
# INFO: Query finished. [astroquery.utils.tap.core]
# 368 2697366592920719744
# INFO: Query finished. [astroquery.utils.tap.core]
# 369 2338596502827873920
# INFO: Query finished. [astroquery.utils.tap.core]
# 370 6473485896644593664
# INFO: Query finished. [astroquery.utils.tap.core]
# 371 3506586608135466752
# INFO: Query finished. [astroquery.utils.tap.core]
# 372 3305633918809117824
# INFO: Query finished. [astroquery.utils.tap.core]
# 373 4449182460449707904
# INFO: Query finished. [astroquery.utils.tap.core]
# 374 4338433743723131648
# INFO: Query finished. [astroquery.utils.tap.core]
# 375 2396530698208685312
# INFO: Query finished. [astroquery.utils.tap.core]
# 376 2318245057994196608
# INFO: Query finished. [astroquery.utils.tap.core]
# 377 3244915072792668416
# INFO: Query finished. [astroquery.utils.tap.core]
# 378 2898839424265628928
# INFO: Query finished. [astroquery.utils.tap.core]
# 379 98692339803443328
# INFO: Query finished. [astroquery.utils.tap.core]
# 380 4094741005901787136
# INFO: Query finished. [astroquery.utils.tap.core]
# 381 3812756203689026048
# INFO: Query finished. [astroquery.utils.tap.core]
# 382 4465274745132375040
# INFO: Query finished. [astroquery.utils.tap.core]
# 383 6572326052043362304
# INFO: Query finished. [astroquery.utils.tap.core]
# 384 6532612963356913408
# INFO: Query finished. [astroquery.utils.tap.core]
# 385 4283815022597925376
# INFO: Query finished. [astroquery.utils.tap.core]
# 386 4175058204312299904
# INFO: Query finished. [astroquery.utils.tap.core]
# 387 22338644598132096
# INFO: Query finished. [astroquery.utils.tap.core]
# 388 577602496345490176
# INFO: Query finished. [astroquery.utils.tap.core]
# 389 4557198933740208128
# INFO: Query finished. [astroquery.utils.tap.core]
# 390 6313600142709958144
# INFO: Query finished. [astroquery.utils.tap.core]
# 391 2326808088911182592
# INFO: Query finished. [astroquery.utils.tap.core]
# 392 610662504594518784
# INFO: Query finished. [astroquery.utils.tap.core]
# 393 2646280705713202816
# INFO: Query finished. [astroquery.utils.tap.core]
# 394 5511171437162508544
# INFO: Query finished. [astroquery.utils.tap.core]
# 395 1745568309317609088
# INFO: Query finished. [astroquery.utils.tap.core]
# 396 6645604928622813568
# INFO: Query finished. [astroquery.utils.tap.core]
# 397 3640244581637740416
# INFO: Query finished. [astroquery.utils.tap.core]
# 398 4129062196940326784
# INFO: Query finished. [astroquery.utils.tap.core]
# 399 6003743571137684736
# INFO: Query finished. [astroquery.utils.tap.core]
# 400 6328672145023976960
# INFO: Query finished. [astroquery.utils.tap.core]
# 401 6378863476442856704
# INFO: Query finished. [astroquery.utils.tap.core]
# 402 672319513203299456
# INFO: Query finished. [astroquery.utils.tap.core]
# 403 740041664173180544
# INFO: Query finished. [astroquery.utils.tap.core]
# 404 5624529024402652288
# INFO: Query finished. [astroquery.utils.tap.core]
# 405 3872347328732372608
# INFO: Query finished. [astroquery.utils.tap.core]
# 406 2799371898696899328
# INFO: Query finished. [astroquery.utils.tap.core]
# 407 5643149082029091328
# INFO: Query finished. [astroquery.utils.tap.core]
# 408 3278753264691218176
# INFO: Query finished. [astroquery.utils.tap.core]
# 409 4308259846169194112
# INFO: Query finished. [astroquery.utils.tap.core]
# 410 31776474454016128
# INFO: Query finished. [astroquery.utils.tap.core]
# 411 2867175035571212416
# INFO: Query finished. [astroquery.utils.tap.core]
# 412 6168626476571025408
# INFO: Query finished. [astroquery.utils.tap.core]
# 413 1462061709995883136
# INFO: Query finished. [astroquery.utils.tap.core]
# 414 1462061709996744448
# INFO: Query finished. [astroquery.utils.tap.core]
# 415 3173510176346843136
# INFO: Query finished. [astroquery.utils.tap.core]
# 416 4737533134341791872
# INFO: Query finished. [astroquery.utils.tap.core]
# 417 4883263814236435840
# INFO: Query finished. [astroquery.utils.tap.core]
# 418 3088637946087230336
# INFO: Query finished. [astroquery.utils.tap.core]
# 419 2502865532882650496
# INFO: Query finished. [astroquery.utils.tap.core]
# 420 4344838261516386944
# INFO: Query finished. [astroquery.utils.tap.core]
# 421 653032704866193024
# INFO: Query finished. [astroquery.utils.tap.core]
# 422 5640768604986959616
# INFO: Query finished. [astroquery.utils.tap.core]
# 423 3728535399707693696
# INFO: Query finished. [astroquery.utils.tap.core]
# 424 5617244278837970816
# INFO: Query finished. [astroquery.utils.tap.core]
# 425 5018408013925502720
# INFO: Query finished. [astroquery.utils.tap.core]
# 426 6171492113110925312
# INFO: Query finished. [astroquery.utils.tap.core]
# 427 4216680418835844864
# INFO: Query finished. [astroquery.utils.tap.core]
# 428 3590005765060827776
# INFO: Query finished. [astroquery.utils.tap.core]
# 429 665777212860770560
# INFO: Query finished. [astroquery.utils.tap.core]
# 430 6471497502884511232
# INFO: Query finished. [astroquery.utils.tap.core]
# 431 4292775149013257984
# INFO: Query finished. [astroquery.utils.tap.core]
# 432 4267889936728496768
# INFO: Query finished. [astroquery.utils.tap.core]
# 433 2848273159379049344
# INFO: Query finished. [astroquery.utils.tap.core]
# 434 5789842624864892288
# INFO: Query finished. [astroquery.utils.tap.core]
# 435 4223507222112425344
# INFO: Query finished. [astroquery.utils.tap.core]
# 436 1787035389632452096
# INFO: Query finished. [astroquery.utils.tap.core]
# 437 5788811970149449472
# INFO: Query finished. [astroquery.utils.tap.core]
# 438 3171511573443110144
# INFO: Query finished. [astroquery.utils.tap.core]
# 439 1179258076562854784
# INFO: Query finished. [astroquery.utils.tap.core]
# 440 2627740779300864896
# INFO: Query finished. [astroquery.utils.tap.core]
# 441 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 442 2821836531864437760
# INFO: Query finished. [astroquery.utils.tap.core]
# 443 6508401923473282432
# INFO: Query finished. [astroquery.utils.tap.core]
# 444 4367318326501438976
# INFO: Query finished. [astroquery.utils.tap.core]
# 445 4194013711756457344
# INFO: Query finished. [astroquery.utils.tap.core]
# 446 6827751124390424320
# INFO: Query finished. [astroquery.utils.tap.core]
# 447 2747724882602989440
# INFO: Query finished. [astroquery.utils.tap.core]
# 448 3482765551281619456
# INFO: Query finished. [astroquery.utils.tap.core]
# 449 2783518212334778880
# INFO: Query finished. [astroquery.utils.tap.core]
# 450 4531962186952439808
# INFO: Query finished. [astroquery.utils.tap.core]
# 451 4833306713154584704
# INFO: Query finished. [astroquery.utils.tap.core]
# 452 6917452439784507648
# INFO: Query finished. [astroquery.utils.tap.core]
# 453 1885985702351337472
# INFO: Query finished. [astroquery.utils.tap.core]
# 454 6891134705556330880
# INFO: Query finished. [astroquery.utils.tap.core]
# 455 61689890880210176
# INFO: Query finished. [astroquery.utils.tap.core]
# 456 1823476232957094400
# INFO: Query finished. [astroquery.utils.tap.core]
# 457 5220352638838227584
# INFO: Query finished. [astroquery.utils.tap.core]
# 458 5743705394673617664
# INFO: Query finished. [astroquery.utils.tap.core]
# 459 646534556782461056
# INFO: Query finished. [astroquery.utils.tap.core]
# 460 3558078936688219776
# INFO: Query finished. [astroquery.utils.tap.core]
# 461 3862158321981206272
# INFO: Query finished. [astroquery.utils.tap.core]
# 462 4375233191015944192
# INFO: Query finished. [astroquery.utils.tap.core]
# 463 2428543391568489728
# INFO: Query finished. [astroquery.utils.tap.core]
# 464 4978490042416830592
# INFO: Query finished. [astroquery.utils.tap.core]
# 465 6449619519295309696
# INFO: Query finished. [astroquery.utils.tap.core]
# 466 76595798217424384
# INFO: Query finished. [astroquery.utils.tap.core]
# 467 3624358837639705984
# INFO: Query finished. [astroquery.utils.tap.core]
# 468 1747664867537511424
# INFO: Query finished. [astroquery.utils.tap.core]
# 469 4250623755841483776
# INFO: Query finished. [astroquery.utils.tap.core]
# 470 2808231625954596352
# INFO: Query finished. [astroquery.utils.tap.core]
# 471 3564856017123389440
# INFO: Query finished. [astroquery.utils.tap.core]
# 472 6250583867148023424
# INFO: Query finished. [astroquery.utils.tap.core]
# 473 1239215751295421824
# INFO: Query finished. [astroquery.utils.tap.core]
# 474 4807503030677131392
# INFO: Query finished. [astroquery.utils.tap.core]
# 475 5124636303346779008
# INFO: Query finished. [astroquery.utils.tap.core]
# 476 6400160947954197888
# INFO: Query finished. [astroquery.utils.tap.core]
# 477 619837589826152960
# INFO: Query finished. [astroquery.utils.tap.core]
# 478 1223126735087115520
# INFO: Query finished. [astroquery.utils.tap.core]
# 479 3022099969137163904
# INFO: Query finished. [astroquery.utils.tap.core]
# 480 5721905003970002688
# INFO: Query finished. [astroquery.utils.tap.core]
# 481 306637167168935168
# INFO: Query finished. [astroquery.utils.tap.core]
# 482 1750950934132331776
# INFO: Query finished. [astroquery.utils.tap.core]
# 483 26101272172092160
# INFO: Query finished. [astroquery.utils.tap.core]
# 484 1893671013749932928
# INFO: Query finished. [astroquery.utils.tap.core]
# 485 5027726757224514176
# INFO: Query finished. [astroquery.utils.tap.core]
# 486 6557995597306666752
# INFO: Query finished. [astroquery.utils.tap.core]
# 487 4986970575602213632
# INFO: Query finished. [astroquery.utils.tap.core]
# 488 4209564315167068032
# INFO: Query finished. [astroquery.utils.tap.core]
# 489 2414870582223963904
# INFO: Query finished. [astroquery.utils.tap.core]
# 490 2586727273302673664
# INFO: Query finished. [astroquery.utils.tap.core]
# 491 3514045832457321856
# INFO: Query finished. [astroquery.utils.tap.core]
# 492 2715770081106897408
# INFO: Query finished. [astroquery.utils.tap.core]
# 493 5086349006368126208
# INFO: Query finished. [astroquery.utils.tap.core]
# 494 4447282646096831360
# INFO: Query finished. [astroquery.utils.tap.core]
# 495 4924960147020781824
# INFO: Query finished. [astroquery.utils.tap.core]
# 496 2781832072598141568
# INFO: Query finished. [astroquery.utils.tap.core]
# 497 6206643671653125888
# INFO: Query finished. [astroquery.utils.tap.core]
# 498 6284731365410978048
# INFO: Query finished. [astroquery.utils.tap.core]
# 499 4945163737603798656
# INFO: Query finished. [astroquery.utils.tap.core]
# 500 6855520385765481088
# INFO: Query finished. [astroquery.utils.tap.core]
# 501 5074604160596736640
# INFO: Query finished. [astroquery.utils.tap.core]
# 502 6447055599914866816
# INFO: Query finished. [astroquery.utils.tap.core]
# 503 6626588256543082496
# INFO: Query finished. [astroquery.utils.tap.core]
# 504 2464228213246255744
# INFO: Query finished. [astroquery.utils.tap.core]
# 505 1161042158187967232
# INFO: Query finished. [astroquery.utils.tap.core]
# 506 2491050180930470272
# INFO: Query finished. [astroquery.utils.tap.core]
# 507 2533723464155234176
# INFO: Query finished. [astroquery.utils.tap.core]
# 508 6461349869550781184
# INFO: Query finished. [astroquery.utils.tap.core]
# 509 5091077112523802112
# INFO: Query finished. [astroquery.utils.tap.core]
# 510 2415330079301474432
# INFO: Query finished. [astroquery.utils.tap.core]
# 511 3314150048683152896
# INFO: Query finished. [astroquery.utils.tap.core]
# 512 4130977099522868736
# INFO: Query finished. [astroquery.utils.tap.core]
# 513 6382640367603744128
# INFO: Query finished. [astroquery.utils.tap.core]
# 514 3299288705924697600
# INFO: Query finished. [astroquery.utils.tap.core]
# 515 6844229329061159040
# INFO: Query finished. [astroquery.utils.tap.core]
# 516 4890157064946814208
# INFO: Query finished. [astroquery.utils.tap.core]
# 517 4237352925367365632
# INFO: Query finished. [astroquery.utils.tap.core]
# 518 2829322183120727808
# INFO: Query finished. [astroquery.utils.tap.core]
# 519 2760239627030471552
# INFO: Query finished. [astroquery.utils.tap.core]
# 520 1256682077618503552
# INFO: Query finished. [astroquery.utils.tap.core]
# 521 3721114933170707328
# INFO: Query finished. [astroquery.utils.tap.core]
# 522 6815349384847296512
# INFO: Query finished. [astroquery.utils.tap.core]
# 523 2639991331699321472
# INFO: Query finished. [astroquery.utils.tap.core]
# 524 2824857169479385856
# INFO: Query finished. [astroquery.utils.tap.core]
# 525 3950979864865999104
# INFO: Query finished. [astroquery.utils.tap.core]
# 526 639908246878533632
# INFO: Query finished. [astroquery.utils.tap.core]
# 527 3312921378798754304
# INFO: Query finished. [astroquery.utils.tap.core]
# 528 5816012513445323904
# INFO: Query finished. [astroquery.utils.tap.core]
# 529 3662665715376647296
# INFO: Query finished. [astroquery.utils.tap.core]
# 530 2739454424859020800
# INFO: Query finished. [astroquery.utils.tap.core]
# 531 3545469496823737856
# INFO: Query finished. [astroquery.utils.tap.core]
# 532 1739640635973968384
# INFO: Query finished. [astroquery.utils.tap.core]
# 533 6481436022845995648
# INFO: Query finished. [astroquery.utils.tap.core]
# 534 3620929357793445376
# INFO: Query finished. [astroquery.utils.tap.core]
# 535 2487396916108233344
# INFO: Query finished. [astroquery.utils.tap.core]
# 536 6606871814033940608
# INFO: Query finished. [astroquery.utils.tap.core]
# 537 6609340148918886144
# INFO: Query finished. [astroquery.utils.tap.core]
# 538 2604115877897249408
# INFO: Query finished. [astroquery.utils.tap.core]
# 539 4497494077967197568
# INFO: Query finished. [astroquery.utils.tap.core]
# 540 6883313741909573632
# INFO: Query finished. [astroquery.utils.tap.core]
# 541 3739313121921154432
# INFO: Query finished. [astroquery.utils.tap.core]
# 542 1215878582637096064
# INFO: Query finished. [astroquery.utils.tap.core]
# 543 6663512777585933056
# INFO: Query finished. [astroquery.utils.tap.core]
# 544 3220926542276901888
# INFO: Query finished. [astroquery.utils.tap.core]
# 545 4869267924568297856
# INFO: Query finished. [astroquery.utils.tap.core]
# 546 4008018301867181952
# INFO: Query finished. [astroquery.utils.tap.core]
# 547 3132297422523121408
# INFO: Query finished. [astroquery.utils.tap.core]
# 548 4763897739549071744
# INFO: Query finished. [astroquery.utils.tap.core]
# 549 4338903029029649920
# INFO: Query finished. [astroquery.utils.tap.core]
# 550 3101901526654756864
# INFO: Query finished. [astroquery.utils.tap.core]
# 551 5441277682006032896
# INFO: Query finished. [astroquery.utils.tap.core]
# 552 4154598526336121600
# INFO: Query finished. [astroquery.utils.tap.core]
# 553 6504605481621314304
# INFO: Query finished. [astroquery.utils.tap.core]
# 554 6026895540811552512
# INFO: Query finished. [astroquery.utils.tap.core]
# 555 5301532910913824384
# INFO: Query finished. [astroquery.utils.tap.core]
# 556 4150826170635895424
# INFO: Query finished. [astroquery.utils.tap.core]
# 557 6409848126430574592
# INFO: Query finished. [astroquery.utils.tap.core]
# 558 4901926404913922816
# INFO: Query finished. [astroquery.utils.tap.core]
# 559 3661529477483653760
# INFO: Query finished. [astroquery.utils.tap.core]
# 560 1223126528928684544
# INFO: Query finished. [astroquery.utils.tap.core]
# 561 3937082209689968896
# INFO: Query finished. [astroquery.utils.tap.core]
# 562 694917878769233408
# INFO: Query finished. [astroquery.utils.tap.core]
# 563 3307504222447587584
# INFO: Query finished. [astroquery.utils.tap.core]
# 564 2026408043220034176
# INFO: Query finished. [astroquery.utils.tap.core]
# 565 2664042942398600064
# INFO: Query finished. [astroquery.utils.tap.core]
# 566 4309238269733772928
# INFO: Query finished. [astroquery.utils.tap.core]
# 567 6575396919300029312
# INFO: Query finished. [astroquery.utils.tap.core]
# 568 5489716460606576768
# INFO: Query finished. [astroquery.utils.tap.core]
# 569 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 570 6832674634380238848
# INFO: Query finished. [astroquery.utils.tap.core]
# 571 5926497386032348160
# INFO: Query finished. [astroquery.utils.tap.core]
# 572 3035245970683433344
# INFO: Query finished. [astroquery.utils.tap.core]
# 573 3522701909545607424
# INFO: Query finished. [astroquery.utils.tap.core]
# 574 2692798534424338304
# INFO: Query finished. [astroquery.utils.tap.core]
# 575 6621799127490124288
# INFO: Query finished. [astroquery.utils.tap.core]
# 576 2379928652449359616
# INFO: Query finished. [astroquery.utils.tap.core]
# 577 2722184666306107008
# INFO: Query finished. [astroquery.utils.tap.core]
# 578 676689831406224128
# INFO: Query finished. [astroquery.utils.tap.core]
# 579 3057712188691831936
# INFO: Query finished. [astroquery.utils.tap.core]
# 580 3995447791584993024
# INFO: Query finished. [astroquery.utils.tap.core]
# 581 4704272495284592512
# INFO: Query finished. [astroquery.utils.tap.core]
# 582 6772521384023709696
# INFO: Query finished. [astroquery.utils.tap.core]
# 583 3010782833390635264
# INFO: Query finished. [astroquery.utils.tap.core]
# 584 4216298411563165440
# INFO: Query finished. [astroquery.utils.tap.core]
# 585 5074705521824867200
# INFO: Query finished. [astroquery.utils.tap.core]
# 586 6408837125489405184
# INFO: Query finished. [astroquery.utils.tap.core]
# 587 3629177859665179904
# INFO: Query finished. [astroquery.utils.tap.core]
# 588 6521229719476231936
# INFO: Query finished. [astroquery.utils.tap.core]
# 589 4703372476296595584
# INFO: Query finished. [astroquery.utils.tap.core]
# 590 2518617548778913024
# INFO: Query finished. [astroquery.utils.tap.core]
# 591 3863564945245771392
# INFO: Query finished. [astroquery.utils.tap.core]
# 592 2637463382668201856
# INFO: Query finished. [astroquery.utils.tap.core]
# 593 4764027962957023104
# INFO: Query finished. [astroquery.utils.tap.core]
# 594 145421309108301184
# INFO: Query finished. [astroquery.utils.tap.core]
# 595 3279109746977266688
# INFO: Query finished. [astroquery.utils.tap.core]
# 596 4794632903476180096
# INFO: Query finished. [astroquery.utils.tap.core]
# 597 3498481592531208576
# INFO: Query finished. [astroquery.utils.tap.core]
# 598 4149820284980989184
# INFO: Query finished. [astroquery.utils.tap.core]
# 599 4900915958024013952
# INFO: Query finished. [astroquery.utils.tap.core]
# 600 5091491662767333376
# INFO: Query finished. [astroquery.utils.tap.core]
# 601 5270707831848147200
# INFO: Query finished. [astroquery.utils.tap.core]
# 602 3863754056950355840
# INFO: Query finished. [astroquery.utils.tap.core]
# 603 4469644028247872640
# INFO: Query finished. [astroquery.utils.tap.core]
# 604 3007203682525892096
# INFO: Query finished. [astroquery.utils.tap.core]
# 605 2820070445609210624
# INFO: Query finished. [astroquery.utils.tap.core]
# 606 1193932021308741888
# INFO: Query finished. [astroquery.utils.tap.core]
# 607 4864752883148063488
# INFO: Query finished. [astroquery.utils.tap.core]
# 608 3112891347231757312
# INFO: Query finished. [astroquery.utils.tap.core]
# 609 4216415956227534208
# INFO: Query finished. [astroquery.utils.tap.core]
# 610 4070388266455534720
# INFO: Query finished. [astroquery.utils.tap.core]
# 611 2815543034682035840
# INFO: Query finished. [astroquery.utils.tap.core]
# 612 2556039491454250112
# INFO: Query finished. [astroquery.utils.tap.core]
# 613 610304716643271808
# INFO: Query finished. [astroquery.utils.tap.core]
# 614 5016175391142088576
# INFO: Query finished. [astroquery.utils.tap.core]
# 615 4734412548543497728
# INFO: Query finished. [astroquery.utils.tap.core]
# 616 6595319039202679680
# INFO: Query finished. [astroquery.utils.tap.core]
# 617 5447325648792896384
# INFO: Query finished. [astroquery.utils.tap.core]
# 618 6661911579416783616
# INFO: Query finished. [astroquery.utils.tap.core]
# 619 6678530491511225856
# INFO: Query finished. [astroquery.utils.tap.core]
# 620 91887977735200000
# INFO: Query finished. [astroquery.utils.tap.core]
# 621 5467029511341033344
# INFO: Query finished. [astroquery.utils.tap.core]
# 622 4938555161620867072
# INFO: Query finished. [astroquery.utils.tap.core]
# 623 6807019282894453504
# INFO: Query finished. [astroquery.utils.tap.core]
# 624 3271668905115228672
# INFO: Query finished. [astroquery.utils.tap.core]
# 625 5069260705884398464
# INFO: Query finished. [astroquery.utils.tap.core]
# 626 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 627 5569393154830167552
# INFO: Query finished. [astroquery.utils.tap.core]
# 628 4627857193068402816
# INFO: Query finished. [astroquery.utils.tap.core]
# 629 2411641904984410624
# INFO: Query finished. [astroquery.utils.tap.core]
# 630 5114013749714071296
# INFO: Query finished. [astroquery.utils.tap.core]
# 631 5252255484129075584
# INFO: Query finished. [astroquery.utils.tap.core]
# ...
# 4319 4219087666404378624
# INFO: Query finished. [astroquery.utils.tap.core]
# 4320 4229021960117124992
# INFO: Query finished. [astroquery.utils.tap.core]
# 4321 2928798848387843456
# INFO: Query finished. [astroquery.utils.tap.core]
# 4322 4237920204651836800
# INFO: Query finished. [astroquery.utils.tap.core]
# 4323 1167838720595878400
# INFO: Query finished. [astroquery.utils.tap.core]
# 4324 2510183229442059776
# INFO: Query finished. [astroquery.utils.tap.core]
# 4325 6855818185917435392
# INFO: Query finished. [astroquery.utils.tap.core]
# 4326 5504204553528873472
# INFO: Query finished. [astroquery.utils.tap.core]
# 4327 666427539629086976
# INFO: Query finished. [astroquery.utils.tap.core]
# 4328 3954927249047809920
# INFO: Query finished. [astroquery.utils.tap.core]
# 4329 3954927249048246272
# INFO: Query finished. [astroquery.utils.tap.core]
# 4330 5607942273021322880
# INFO: Query finished. [astroquery.utils.tap.core]
# 4331 5799828080244639488
# INFO: Query finished. [astroquery.utils.tap.core]
# 4332 3048519339470667520
# INFO: Query finished. [astroquery.utils.tap.core]
# 4333 1271209615518148736
# INFO: Query finished. [astroquery.utils.tap.core]
# 4334 1271209611223823232
# INFO: Query finished. [astroquery.utils.tap.core]
# 4335 1896891139712235008
# INFO: Query finished. [astroquery.utils.tap.core]
# 4336 5663558453071724288
# INFO: Query finished. [astroquery.utils.tap.core]
# 4337 3234481566438473600
# INFO: Query finished. [astroquery.utils.tap.core]
# 4338 3545597177611374848
# INFO: Query finished. [astroquery.utils.tap.core]
# 4339 3591819100253606784
# INFO: Query finished. [astroquery.utils.tap.core]
# 4340 4763906879239461632
# INFO: Query finished. [astroquery.utils.tap.core]
# 4341 2598586816173411200
# INFO: Query finished. [astroquery.utils.tap.core]
# 4342 4852609086456829696
# INFO: Query finished. [astroquery.utils.tap.core]
# 4343 3900151160300881536
# INFO: Query finished. [astroquery.utils.tap.core]
# 4344 3326288347818354048
# INFO: Query finished. [astroquery.utils.tap.core]
# 4345 3988038079645800960
# INFO: Query finished. [astroquery.utils.tap.core]
# 4346 4901229043960053248
# INFO: Query finished. [astroquery.utils.tap.core]
# 4347 4511848202267498624
# INFO: Query finished. [astroquery.utils.tap.core]
# 4348 4511848202261111424
# INFO: Query finished. [astroquery.utils.tap.core]
# 4349 2525176376157018112
# INFO: Query finished. [astroquery.utils.tap.core]
# 4350 5308184548267955968
# INFO: Query finished. [astroquery.utils.tap.core]
# 4351 4321170827084026368
# INFO: Query finished. [astroquery.utils.tap.core]
# 4352 6472858766996632704
# INFO: Query finished. [astroquery.utils.tap.core]
# 4353 4409032079673958528
# INFO: Query finished. [astroquery.utils.tap.core]
# 4354 2831490694929214464
# INFO: Query finished. [astroquery.utils.tap.core]
# 4355 6441664350807003520
# INFO: Query finished. [astroquery.utils.tap.core]
# 4356 3307815006281475200
# INFO: Query finished. [astroquery.utils.tap.core]
# 4357 5826466017192283264
# INFO: Query finished. [astroquery.utils.tap.core]
# 4358 2968430745003580160
# INFO: Query finished. [astroquery.utils.tap.core]
# 4359 6270906415441316224
# INFO: Query finished. [astroquery.utils.tap.core]
# 4360 3360548511663388032
# INFO: Query finished. [astroquery.utils.tap.core]
# 4361 4832401540206966656
# INFO: Query finished. [astroquery.utils.tap.core]
# 4362 2817129458162461056
# INFO: Query finished. [astroquery.utils.tap.core]
# 4363 4052127925286198400
# INFO: Query finished. [astroquery.utils.tap.core]
# 4364 3400292798990117888
# INFO: Query finished. [astroquery.utils.tap.core]
# 4365 164282846968545152
# INFO: Query finished. [astroquery.utils.tap.core]
# 4366 725398123501434496
# INFO: Query finished. [astroquery.utils.tap.core]
# 4367 6270906415441315840
# INFO: Query finished. [astroquery.utils.tap.core]
# 4368 6770313530317154560
# INFO: Query finished. [astroquery.utils.tap.core]
# 4369 3349058065397818880
# INFO: Query finished. [astroquery.utils.tap.core]
# 4370 3312709379213017728
# INFO: Query finished. [astroquery.utils.tap.core]
# 4371 1807876151501164032
# INFO: Query finished. [astroquery.utils.tap.core]
# 4372 6053512007260865280
# INFO: Query finished. [astroquery.utils.tap.core]
# 4373 4714764481913306496
# INFO: Query finished. [astroquery.utils.tap.core]
# 4374 1230894097540611968
# INFO: Query finished. [astroquery.utils.tap.core]
# 4375 3261733202649972992
# INFO: Query finished. [astroquery.utils.tap.core]
# 4376 6708063202046601344
# INFO: Query finished. [astroquery.utils.tap.core]
# 4377 2648705785983069056
# INFO: Query finished. [astroquery.utils.tap.core]
# 4378 5091025641634025984
# INFO: Query finished. [astroquery.utils.tap.core]
# 4379 6395705074002990592
# INFO: Query finished. [astroquery.utils.tap.core]
# 4380 3656209284314369664
# INFO: Query finished. [astroquery.utils.tap.core]
# 4381 867679158680505600
# INFO: Query finished. [astroquery.utils.tap.core]
# 4382 4228891221313732864
# INFO: Query finished. [astroquery.utils.tap.core]
# 4383 5493209501673364736
# INFO: Query finished. [astroquery.utils.tap.core]
# 4384 5359339601617743232
# INFO: Query finished. [astroquery.utils.tap.core]
# 4385 4967153630858709120
# INFO: Query finished. [astroquery.utils.tap.core]
# 4386 6401464693866921472
# INFO: Query finished. [astroquery.utils.tap.core]
# 4387 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 4388 3172940045207078784
# INFO: Query finished. [astroquery.utils.tap.core]
# 4389 5725940142928541184
# INFO: Query finished. [astroquery.utils.tap.core]
# 4390 5567900121118276736
# INFO: Query finished. [astroquery.utils.tap.core]
# 4391 6502570319958250624
# INFO: Query finished. [astroquery.utils.tap.core]
# 4392 4245501440394297088
# INFO: Query finished. [astroquery.utils.tap.core]
# 4393 145293181643038336
# INFO: Query finished. [astroquery.utils.tap.core]
# 4394 4143169446523028608
# INFO: Query finished. [astroquery.utils.tap.core]
# 4395 6552638987109514880
# INFO: Query finished. [astroquery.utils.tap.core]
# 4396 6205244027709918976
# INFO: Query finished. [astroquery.utils.tap.core]
# 4397 144978858756826368
# INFO: Query finished. [astroquery.utils.tap.core]
# 4398 2473608009504466688
# INFO: Query finished. [astroquery.utils.tap.core]
# 4399 1784061008815679232
# INFO: Query finished. [astroquery.utils.tap.core]
# 4400 5544588992843877632
# INFO: Query finished. [astroquery.utils.tap.core]
# 4401 4842770347173769728
# INFO: Query finished. [astroquery.utils.tap.core]
# 4402 3102372804823186176
# INFO: Query finished. [astroquery.utils.tap.core]
# 4403 4962094636124753792
# INFO: Query finished. [astroquery.utils.tap.core]
# 4404 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 4405 594989348593414016
# INFO: Query finished. [astroquery.utils.tap.core]
# 4406 6317407201723597952
# INFO: Query finished. [astroquery.utils.tap.core]
# 4407 6489909443564308224
# INFO: Query finished. [astroquery.utils.tap.core]
# 4408 145373377272257664
# INFO: Query finished. [astroquery.utils.tap.core]
# 4409 2431157720981843200
# INFO: Query finished. [astroquery.utils.tap.core]
# 4410 6851090320276640000
# INFO: Query finished. [astroquery.utils.tap.core]
# 4411 6855818185917435776
# INFO: Query finished. [astroquery.utils.tap.core]
# 4412 3220137750059767680
# INFO: Query finished. [astroquery.utils.tap.core]
# 4413 105599987244856064
# INFO: Query finished. [astroquery.utils.tap.core]
# 4414 1241384331823317632
# INFO: Query finished. [astroquery.utils.tap.core]
# 4415 107774202769886848
# INFO: Query finished. [astroquery.utils.tap.core]
# 4416 6612887104710588928
# INFO: Query finished. [astroquery.utils.tap.core]
# 4417 1236764218322666880
# INFO: Query finished. [astroquery.utils.tap.core]
# 4418 3790864411783833600
# INFO: Query finished. [astroquery.utils.tap.core]
# 4419 3256786534197166208
# INFO: Query finished. [astroquery.utils.tap.core]
# 4420 4813785605758514688
# INFO: Query finished. [astroquery.utils.tap.core]
# 4421 3284145132275338496
# INFO: Query finished. [astroquery.utils.tap.core]
# 4422 5125873666245425920
# INFO: Query finished. [astroquery.utils.tap.core]
# 4423 4819441459212276864
# INFO: Query finished. [astroquery.utils.tap.core]
# 4424 4004194097346057728
# INFO: Query finished. [astroquery.utils.tap.core]
# 4425 2964000159820118400
# INFO: Query finished. [astroquery.utils.tap.core]
# 4426 4910240675621946880
# INFO: Query finished. [astroquery.utils.tap.core]
# 4427 656046844193198848
# INFO: Query finished. [astroquery.utils.tap.core]
# 4428 5224975398040550400
# INFO: Query finished. [astroquery.utils.tap.core]
# 4429 2657361038437686144
# INFO: Query finished. [astroquery.utils.tap.core]
# 4430 4937183864463433216
# INFO: Query finished. [astroquery.utils.tap.core]
# 4431 64115585330656000
# INFO: Query finished. [astroquery.utils.tap.core]
# 4432 6802426038708609536
# INFO: Query finished. [astroquery.utils.tap.core]
# 4433 865962683591073408
# INFO: Query finished. [astroquery.utils.tap.core]
# 4434 2605300640331419904
# INFO: Query finished. [astroquery.utils.tap.core]
# 4435 1805044913356835328
# INFO: Query finished. [astroquery.utils.tap.core]
# 4436 1743504800870418432
# INFO: Query finished. [astroquery.utils.tap.core]
# 4437 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 4438 5064574720469473792
# INFO: Query finished. [astroquery.utils.tap.core]
# 4439 2328281189678351232
# INFO: Query finished. [astroquery.utils.tap.core]
# 4440 5584019442620181760
# INFO: Query finished. [astroquery.utils.tap.core]
# 4441 6298822878231170944
# INFO: Query finished. [astroquery.utils.tap.core]
# 4442 2750176827892427904
# INFO: Query finished. [astroquery.utils.tap.core]
# 4443 3241699825915136768
# INFO: Query finished. [astroquery.utils.tap.core]
# 4444 4532560355639207680
# INFO: Query finished. [astroquery.utils.tap.core]
# 4445 5538573431596682496
# INFO: Query finished. [astroquery.utils.tap.core]
# 4446 2430993550151504896
# INFO: Query finished. [astroquery.utils.tap.core]
# 4447 2552059469815827456
# INFO: Query finished. [astroquery.utils.tap.core]
# 4448 5836174636208941184
# INFO: Query finished. [astroquery.utils.tap.core]
# 4449 2498460442625153536
# INFO: Query finished. [astroquery.utils.tap.core]
# 4450 4976894960284258176
# INFO: Query finished. [astroquery.utils.tap.core]
# 4451 3618910139048607616
# INFO: Query finished. [astroquery.utils.tap.core]
# 4452 4482248936925366400
# INFO: Query finished. [astroquery.utils.tap.core]
# 4453 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 4454 5625458592767153280
# INFO: Query finished. [astroquery.utils.tap.core]
# 4455 6179271776352879872
# INFO: Query finished. [astroquery.utils.tap.core]
# 4456 5888394257280681856
# INFO: Query finished. [astroquery.utils.tap.core]
# 4457 2583819069342416384
# INFO: Query finished. [astroquery.utils.tap.core]
# 4458 6101125121284959360
# INFO: Query finished. [astroquery.utils.tap.core]
# 4459 5994934563174251264
# INFO: Query finished. [astroquery.utils.tap.core]
# 4460 3163696103058961920
# INFO: Query finished. [astroquery.utils.tap.core]
# 4461 6698960688866464768
# INFO: Query finished. [astroquery.utils.tap.core]
# 4462 4283652432293739392
# INFO: Query finished. [astroquery.utils.tap.core]
# 4463 3102372804823185920
# INFO: Query finished. [astroquery.utils.tap.core]
# 4464 3974220242141965056
# INFO: Query finished. [astroquery.utils.tap.core]
# 4465 3422042582096699520
# INFO: Query finished. [astroquery.utils.tap.core]
# 4466 1789231256087445120
# INFO: Query finished. [astroquery.utils.tap.core]
# 4467 5591534810757825280
# INFO: Query finished. [astroquery.utils.tap.core]
# 4468 6223455960353208192
# INFO: Query finished. [astroquery.utils.tap.core]
# 4469 5504529287416164992
# INFO: Query finished. [astroquery.utils.tap.core]
# 4470 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 4471 3070628701538299648
# INFO: Query finished. [astroquery.utils.tap.core]
# 4472 nan
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 5 seconds... (Attempt 1/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 10 seconds... (Attempt 2/3)
# 500 Error 500:
# null
# An HTTP error occurred: Error 500:
# null
# Retrying in 20 seconds... (Attempt 3/3)
# Failed to execute query after several attempts.
# 4473 1442169070749457664
# INFO: Query finished. [astroquery.utils.tap.core]
# 4474 3027656351155128704
# INFO: Query finished. [astroquery.utils.tap.core]
# 4475 4297465218928881792
# INFO: Query finished. [astroquery.utils.tap.core]
# 4476 6742328107526267904
# INFO: Query finished. [astroquery.utils.tap.core]
# 4477 6408937971321777152
# INFO: Query finished. [astroquery.utils.tap.core]
# 4478 5830704393965928704
# INFO: Query finished. [astroquery.utils.tap.core]
# 4479 5830704393979103488
# INFO: Query finished. [astroquery.utils.tap.core]
# 4480 2662112268699428352
# INFO: Query finished. [astroquery.utils.tap.core]
# 4481 5229569879178155264
# INFO: Query finished. [astroquery.utils.tap.core]
# 4482 6347165552647512960
# INFO: Query finished. [astroquery.utils.tap.core]
# 4483 5950107164894727552
# INFO: Query finished. [astroquery.utils.tap.core]
# 4484 4513821963108970368
# INFO: Query finished. [astroquery.utils.tap.core]
# 4485 5317114850417299584
# INFO: Query finished. [astroquery.utils.tap.core]
# 4486 2793413885704410112
# INFO: Query finished. [astroquery.utils.tap.core]
# 4487 42768532716776704
# INFO: Query finished. [astroquery.utils.tap.core]
# 4488 5990339291764655744
# INFO: Query finished. [astroquery.utils.tap.core]
# 4489 6172313448297170304
# INFO: Query finished. [astroquery.utils.tap.core]
# 4490 5908285934423927424
# INFO: Query finished. [astroquery.utils.tap.core]
# 4491 2599883685842959232
# INFO: Query finished. [astroquery.utils.tap.core]
# 4492 1252050659765215744
# INFO: Query finished. [astroquery.utils.tap.core]
# 4493 6668980648908319616
# INFO: Query finished. [astroquery.utils.tap.core]
# 4494 4690114462012051584
# INFO: Query finished. [astroquery.utils.tap.core]
# 4495 4100609962786851200
# INFO: Query finished. [astroquery.utils.tap.core]
# 4496 3163696107354305536
# INFO: Query finished. [astroquery.utils.tap.core]
# 4497 4911275281704066048
# INFO: Query finished. [astroquery.utils.tap.core]
# 4498 5607190344506642432
# INFO: Query finished. [astroquery.utils.tap.core]
# 4499 5593584059906793088
# INFO: Query finished. [astroquery.utils.tap.core]
# 4500 583151353573007104
# INFO: Query finished. [astroquery.utils.tap.core]
# 4501 3131481481815806976
# INFO: Query finished. [astroquery.utils.tap.core]
# 4502 3800758057928927872
# INFO: Query finished. [astroquery.utils.tap.core]
# 4503 5593584059914156800
# INFO: Query finished. [astroquery.utils.tap.core]
# 4504 4762394397915837056
# INFO: Query finished. [astroquery.utils.tap.core]
# 4505 6323603052822806784
# INFO: Query finished. [astroquery.utils.tap.core]
# 4506 6536790454707565696
# INFO: Query finished. [astroquery.utils.tap.core]
# 4507 1273169013960272640
# INFO: Query finished. [astroquery.utils.tap.core]
# 4508 4299567450800546304
# INFO: Query finished. [astroquery.utils.tap.core]
# Rows with bright neighbors: 138
# Rows without bright neighbors: 4371

# %%
bright_neighbors_df
# Out:
#              source_id        source_id_dr2  source_id_dr3         RA  \
# 9  4975284381905517824  4975284381905517824            NaN  11.436031
#
#          DEC     V_mag  Phot G Mean Mag  Phot BP Mean Mag  Phot RP Mean Mag  \
# 9 -47.548651  12.77994        11.892607         13.051886         10.249727
#
#       BP-RP  ...  Radius [R_Sun]  HZ_limit [AU]  RV precision [m/s]  \
# 9  2.802158  ...             NaN       1.025792            0.959914
#
#    HZ Detection Limit [M_Earth]  Spectral Type   HD Number  GJ Number  \
# 9                           NaN              M  HD   4391B        NaN
#
#    HIP Number Object Type HZ Detection Limit Simplified [M_Earth]
# 9         NaN     HighPM*                                     NaN
#
# [1 rows x 24 columns]

# %%
rows_without_bright_neighbors_df
# Out:
#              source_id        source_id_dr2        source_id_dr3          RA  \
# 0    22269508511466624    22269508511466624    22269508511466624   41.482248
# 1  1173206811240350592  1173206811240350592  1173206811240350592  221.961398
# 2  6349915534307041152  6349915534307041152  6349915534307041152  312.940241
# 3  2683023811628007296  2683023811628007296  2683023811628007296  330.540802
# 4  3919427007885527680  3919427007885527680  3919427007885527680  179.383579
# 5  4595398441587270272  4595398441587270272  4595398441587270272  264.878042
# 6  4188969431580611456  4188969431580611456  4188969431580611456  299.618212
# 7  5702187702467261696  5702187702467261696  5702187702467261696  131.046016
# 8  3903318372263850368  3903318372263850368  3903318372263850368  188.750913
#
#          DEC      V_mag  Phot G Mean Mag  Phot BP Mean Mag  Phot RP Mean Mag  \
# 0  10.666519  12.687016        11.891757         12.940540         10.878490
# 1   7.416476  11.617188        10.907482         11.867918          9.918146
# 2 -79.315480  11.810019        10.907413         12.067825          9.833761
# 3   1.398992   9.136045         8.403359          9.387209          7.420015
# 4  11.828810  11.797612        10.899825         12.055270          9.827121
# 5  27.761330  11.072632        10.337281         11.323845          9.354651
# 6 -12.626210  12.081400        11.325941         12.333448         10.330709
# 7 -22.498490  11.270100        10.511396         11.522376          9.510471
# 8   9.827072  11.382888        10.452762         11.641875          9.360346
#
#       BP-RP  ...  Radius [R_Sun]  HZ_limit [AU]  RV precision [m/s]  \
# 0  2.062050  ...        0.659257       0.259182            0.912258
# 1  1.949772  ...        0.872650       0.343274            0.557978
# 2  2.234064  ...        0.367781       0.144694            0.610223
# 3  1.967194  ...        0.702667       0.276365            0.178149
# 4  2.228149  ...        0.548498       0.217990            0.608185
# 5  1.969193  ...        0.757623       0.298467            0.435757
# 6  2.002739  ...        0.574324       0.246834            0.694857
# 7  2.011905  ...        0.600230       0.259745            0.478308
# 8  2.281529  ...        0.501529       0.197819            0.504383
#
#    HZ Detection Limit [M_Earth]  Spectral Type  HD Number  GJ Number  \
# 0                      3.888545              M        NaN        NaN
# 1                      2.912921              M        NaN        NaN
# 2                      1.535877              M        NaN     GJ 808
# 3                      0.795958              M  HD 209290     GJ 846
# 4                      2.008597              M        NaN    GJ 3695
# 5                      1.882718              M        NaN    GJ 4018
# 6                      2.857381              M        NaN        NaN
# 7                      2.046737              M        NaN        NaN
# 8                      1.774141              M        NaN     GJ 476
#
#    HIP Number Object Type HZ Detection Limit Simplified [M_Earth]
# 0         NaN     HighPM*                                3.888505
# 1         NaN     HighPM*                                2.912901
# 2         NaN     HighPM*                                1.535867
# 3      108782     HighPM*                                0.795956
# 4       58321     HighPM*                                2.008582
# 5       86423     HighPM*                                1.882708
# 6         NaN     HighPM*                                2.857359
# 7         NaN     HighPM*                                2.046726
# 8       61413     HighPM*                                1.774131
#
# [9 rows x 24 columns]
